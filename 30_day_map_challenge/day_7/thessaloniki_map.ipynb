# %%
# clean environment
import gc
gc.collect()

# load libraries
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
from shapely.geometry import Point, LineString
import osmnx as ox

print(ox)
print(ox.__file__)
print(ox.__version__)  # 2.0.6

# -------------------------------
# Map data
# -------------------------------

# define place
place_name = "Thessaloniki, Greece"

# get city polygon
gdf_place = ox.geocode_to_gdf(place_name)
polygon = gdf_place.geometry.iloc[0]

# download roads
thess_roads = ox.graph_from_polygon(polygon, network_type='drive')
roads_gdf = ox.graph_to_gdfs(thess_roads, nodes=False, edges=True)

# download water features using 'geometries_from_place' in v1.2.2 style
# in v2.x, use 'geometries.geometries_from_place' is removed
# solution: use 'geometries_from_bbox'
minx, miny, maxx, maxy = polygon.bounds
tags = {'natural': 'water'}
water_gdf = ox.geometries_from_bbox(maxy, miny, maxx, minx, tags)

# plot roads
roads_gdf.plot(ax=ax, color="grey", linewidth=0.5)

# plot metro line
metro_line_gdf.plot(ax=ax, color="#df7775", linewidth=2)

# plot metro stations
metro_gdf.plot(ax=ax, color="#ab403f", markersize=50)

# add labels
for x, y, label in zip(metro_gdf.geometry.x, metro_gdf.geometry.y, metro_gdf['name']):
    ax.text(x, y, label, fontsize=8, ha='left', va='bottom', color='#333333')

# set limits around Thessaloniki
ax.set_xlim(22.9, 23)
ax.set_ylim(40.59, 40.665)

# remove axes
ax.axis('off')

# add title/subtitle/caption
plt.suptitle("Thessaloniki metro: 13 stations, 17 minutes.", fontsize=16, y=0.95)
plt.title("A long-awaited system that covers only a small part of the city.", fontsize=12, color="grey30", y=1.01)
plt.figtext(0.95, 0.02, "30DayChartChallenge 2025: Day 07 | Graphic: Natasa Anastasiadou", 
            horizontalalignment='right', fontsize=9)

# save figure
plt.savefig("Thessaloniki_metro.png", dpi=600, bbox_inches='tight', facecolor='white')
plt.show()
# Out:
# <module 'osmnx' from '/Users/stann-omar.jones/Projects/github-repos/MapScapades/30_day_map_challenge/day_7/.venv/lib/python3.11/site-packages/osmnx/__init__.py'>
# /Users/stann-omar.jones/Projects/github-repos/MapScapades/30_day_map_challenge/day_7/.venv/lib/python3.11/site-packages/osmnx/__init__.py
# 2.0.6
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 36
#      34 minx, miny, maxx, maxy = polygon.bounds
#      35 tags = {'natural': 'water'}
# ---> 36 water_gdf = ox.geometries_from_bbox(maxy, miny, maxx, minx, tags)
#      38 # plot roads
#      39 roads_gdf.plot(ax=ax, color="grey", linewidth=0.5)
#
# AttributeError: module 'osmnx' has no attribute 'geometries_from_bbox'
